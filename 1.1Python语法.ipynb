# %% [markdown]
# # Python基础
# ## 缩进、注释与格式化输出

# %%
# -*- coding: utf-8 -*-
high = 1.2;price = 40       # 初始化定义变量
if high > 1.3:
    print("身高为{}米，请支付全票费用：{}元".format(high, price)) 	#身高超过限制买全票
else:
    print("身高为{0}米，请支付半价费用：{1:.2f}元".format(high, price/2)) # 身高不超限，买半票
# Out:
# 身高为1.2米，请支付半价费用：20.00元

# %% [markdown]
# ## 数据类型：数值、字符串
# * 整数(int)、浮点数(float)、复数(complex)，字符串 的赋值
# * 类型查看：type( )
# * 类型转换
# * 字符串的运算：加、数乘

# %%
x = 3;  y = 8/3;  z = "abc"
print(" 输出1. x = {0}, 类型为：{1}".format(x, type(x)))
print(" 输出2. y = {0:.2f}, 类型为：{1}".format(y, type(y)))
print(" 输出3. z = {0}, 类型为：{1}".format(z, type(z)))
# Out:
#  输出1. x = 3, 类型为：<class 'int'>
#  输出2. y = 2.67, 类型为：<class 'float'>
#  输出3. z = abc, 类型为：<class 'str'>

# %%
print(" 输出4. int(y) = {0}, 类型为：{1}".format(int(y), type(int(y))))
print(" 输出5. str(y) = {0}, 类型为：{1}".format(str(y), type(str(y))))
# Out:
#  输出4. int(y) = 2, 类型为：<class 'int'>
#  输出5. str(y) = 2.6666666666666665, 类型为：<class 'str'>

# %%
print(" 输出6. str(x) + z = {0},\t x * z = {1}".format(str(x) + z, x * z))
# Out:
#  输出6. str(x) + z = 3abc,	 x * z = abcabcabc

# %% [markdown]
# ## 数据类型：列表
# ### 创建、长度、索引 、切片

# %%
L1 = [1, 2, 'a', 'bcd', (3,4)]    # 直接赋值
L2 = list(range(1,8))
    # range(m,n) 生成从 m 到 n-1 之间的整数，用list()将类型转为列表
print("列表为：{}， 其长度为：{}".format(L1, len(L1)))
print("列表为：{}， 其长度为：{}".format(L2, len(L2)))
# Out:
# 列表为：[1, 2, 'a', 'bcd', (3, 4)]， 其长度为：5
# 列表为：[1, 2, 3, 4, 5, 6, 7]， 其长度为：7

# %%
L2 = list(range(1,8));    i = 3
print("0、初始列表为：L2 = {}".format(L2))
print("1、第1个元素为：L2[{}] = {}".format(0,L2[0]))
print("2、第{}个元素为：L2[{}] = {}".format(i+1,i, L2[i]))		# 正向引用索引序号从0开始，对应第1个元素
print("3、倒数第{}个元素为：L2[{}] = {}".format(i, -i,L2[-i]))		# 反向索引从-1开始
# Out:
# 0、初始列表为：L2 = [1, 2, 3, 4, 5, 6, 7]
# 1、第1个元素为：L2[0] = 1
# 2、第4个元素为：L2[3] = 4
# 3、倒数第3个元素为：L2[-3] = 5

# %%
L2 = list(range(1,8));    i = 3
print("0、初始列表为：L2 = {}".format(L2))
print("1、L2[1:{}]={}".format(i,L2[1:i]))
print("2、L2[{}::2]={}".format(i,L2[i::2]))
print("3、L2[:{}]={}".format(-i,L2[:-i]))
# Out:
# 0、初始列表为：L2 = [1, 2, 3, 4, 5, 6, 7]
# 1、L2[1:3]=[2, 3]
# 2、L2[3::2]=[4, 6]
# 3、L2[:-3]=[1, 2, 3, 4]

# %% [markdown]
# ### 复制、增加、删除 、运算
# 列表最好不要直接引用，最好复制，否则可能出错
# * 复制列表的方法有两种：
#     1. List2 = List1[:]
#     2. List2 = List1.copy()

# %%
# 复制
L1 = list(range(1,5));   L2 = L1;
print("0、L1 = {},  L2 = {}".format(L1, L2))
L2[2] = 9
print("1、L1 = {},  L2 = {}".format(L1, L2))         # 等号复制，一个改变，另一个跟随改变
L1 = list(range(1,5));   L2 = L1[:];   L2[2] = 9    # 正确复制，一个改变，不引起另一个改变
print("2、L1 = {},  L2 = {}".format(L1, L2))
# Out:
# 0、L1 = [1, 2, 3, 4],  L2 = [1, 2, 3, 4]
# 1、L1 = [1, 2, 9, 4],  L2 = [1, 2, 9, 4]
# 2、L1 = [1, 2, 3, 4],  L2 = [1, 2, 9, 4]

# %%
L1 = list(range(1,5));   L2 = L1;
print("0、L1 = {},  L2 = {}".format(L1, L2))
L2[2] = 9
print("1、L1 = {},  L2 = {}".format(L1, L2))         # 等号复制，一个改变，另一个跟随改变
print("2、id(L1) = {},  id(L2) = {}".format(id(L1), id(L2)))         # 查看地址
L1 = list(range(1,5));   L2 = L1[:];   L2[2] = 9    # 正确复制，一个改变，不引起另一个改变
print("3、L1 = {},  L2 = {}".format(L1, L2))
print("4、id(L1) = {},  id(L2) = {}".format(id(L1), id(L2)))         # 查看地址
# Out:
# 0、L1 = [1, 2, 3, 4],  L2 = [1, 2, 3, 4]
# 1、L1 = [1, 2, 9, 4],  L2 = [1, 2, 9, 4]
# 2、id(L1) = 139967438625536,  id(L2) = 139967438625536
# 3、L1 = [1, 2, 3, 4],  L2 = [1, 2, 9, 4]
# 4、id(L1) = 139967438159232,  id(L2) = 139967420045696

# %%
# 增加、删除
L1 = list(range(1,5));   L2 = L1[:];  L3 = L1[:];  L4 = L1[:];  L5 = L1[:];  
L2.append(9)   # append() 在列表末尾添加元素
L3.insert(2,9)   # insert() 在列表第2+1个元素前添加元素
L4.remove(3)   # remove() 从列表删除特定元素
L5.pop()       # pop()    从列表末尾删除元素
print("初始列表为：L1 = {}".format(L1))
print("L2.append(9) = {},\t L3.insert(2,9) = {}".format(L2, L3))
print("L4.remove(3) = {},\t L5.pop() = {}".format(L4, L5))
# Out:
# 初始列表为：L1 = [1, 2, 3, 4]
# L2.append(9) = [1, 2, 3, 4, 9],	 L3.insert(2,9) = [1, 2, 9, 3, 4]
# L4.remove(3) = [1, 2, 4],	 L5.pop() = [1, 2, 3]

# %%
# 运算 (连接、数乘重复)
L1 = list(range(1,4));   L2 = ["a", "b"]
print("L1 = {},  L2 = {}".format(L1, L2))
print("L1 + L2 = {}".format(L1 + L2))
print("3  * L2 = {}".format(3 *  L2))
# print("L1 = {},  L2 = {}".format(L1, L2))   # 前面的运算并未赋值，不影响原有列表
# Out:
# L1 = [1, 2, 3],  L2 = ['a', 'b']
# L1 + L2 = [1, 2, 3, 'a', 'b']
# 3  * L2 = ['a', 'b', 'a', 'b', 'a', 'b']

# %% [markdown]
# ### 排序、频数、最大值、最小值

# %%
# 排序
L0 = [1,2,3,4,5,4,3];  L1 = L0[:];  L2 = L0[:];  L1.sort()
print("0、初始列表为：{}".format(L0))
print("1、L1.sort()={}".format(L1))    # list.sort()排序且改变原列表
print("2、sorted(L2)={},\t L2={}".format(sorted(L2), L2))    # sorted(list) 返回排序列表，但不改变原列表
# Out:
# 0、初始列表为：[1, 2, 3, 4, 5, 4, 3]
# 1、L1.sort()=[1, 2, 3, 3, 4, 4, 5]
# 2、sorted(L2)=[1, 2, 3, 3, 4, 4, 5],	 L2=[1, 2, 3, 4, 5, 4, 3]

# %%
# 逆序
L0 = [1,2,3,4,5,4,3];  L1 = L0[:];  L2 = L0[:]
L1.reverse();    L2 = L2[::-1]
print("0、初始列表为：{}".format(L0))
print("1、L1.reverse()={}".format(L1))
print("2、L2[::-1]={}".format(L2))
# Out:
# 0、初始列表为：[1, 2, 3, 4, 5, 4, 3]
# 1、L1.reverse()=[3, 4, 5, 4, 3, 2, 1]
# 2、L2[::-1]=[3, 4, 5, 4, 3, 2, 1]

# %%
# 频数、位置、极值、求和
L1 = [1,2,3,4,5,4,3];   item1 = 3
print("0、初始列表为：{}".format(L1))
print("1、元素{}出现的次数为：{}".format(item1, L1.count(item1)))     # Count an item
print("2、元素{}第一次出现的索引号为：{}".format(item1,L1.index(item1)))      # Get the index of an item，注意序号从0开始的
print("3、max(L1) = {}， min(L1) = {}， sum(L1) = {}".format(max(L1),min(L1),sum(L1)))          # max, min, sum
# Out:
# 0、初始列表为：[1, 2, 3, 4, 5, 4, 3]
# 1、元素3出现的次数为：2
# 2、元素3第一次出现的索引号为：2
# 3、max(L1) = 5， min(L1) = 1， sum(L1) = 22

# %% [markdown]
# ### 判断、与字符串的转换

# %%
# 判断
L1 = list(range(5))
print("0、初始列表为：{}".format(L1))
print("1、列表包含元素{}？-> {}".format(5, 5 in L1))
print("2、列表不包含元素{}？-> {}".format(5, 5 not in L1))
print("3、列表所有元素>0：{}".format(all(L1)))
print("4、列表任一元素>0：{}".format(any(L1)))
# Out:
# 0、初始列表为：[0, 1, 2, 3, 4]
# 1、列表包含元素5？-> False
# 2、列表不包含元素5？-> True
# 3、列表所有元素>0：False
# 4、列表任一元素>0：True

# %%
# 与字符串的转换
str1 = "我爱中国";    L1 = list(str1)
print("0、初始字符串为：{}".format(str1))
print("1、list(str)转换为：{}".format(L1))
str2 = "我.爱.中.国";    L2 = str2.split('.')
print("2、初始字符串为：{}".format(str2))
print("3、str.split()转换为：{}".format(L2))
str3 = '-'.join(L2)
print("4、'连接符'.join(list)转换为：{}".format(str3))
# Out:
# 0、初始字符串为：我爱中国
# 1、list(str)转换为：['我', '爱', '中', '国']
# 2、初始字符串为：我.爱.中.国
# 3、str.split()转换为：['我', '爱', '中', '国']
# 4、'连接符'.join(list)转换为：我-爱-中-国

# %% [markdown]
# ## 数据类型：元组

# %%
# 元组
T1 = (1,2,3);   L1 = list(T1);   T2 = tuple(L1)
print("0、初始元组： T1={}".format(T1))
print("1、L1 = list(T1)={}".format(L1))
print("2、T2 = tuple(L1)={}".format(T2))
x,y,z = T1    # 将元组的元素 解包 为变量
print("3、x={}, y={}, z={}".format(x,y,z))
# Out:
# 0、初始元组： T1=(1, 2, 3)
# 1、L1 = list(T1)=[1, 2, 3]
# 2、T2 = tuple(L1)=(1, 2, 3)
# 3、x=1, y=2, z=3

# %% [markdown]
# ## 数据类型：字典

# %%
# 字典
# 英语成绩 = {"张三":85, "李四":75, "王五":95}
数学成绩 = {"张三":88, "李四":92, "王五":78}
print("1、张三的数学成绩为：{}".format(数学成绩["张三"]))
print("2、键为：{}".format(数学成绩.keys()))
print("3、值为：{}".format(数学成绩.values()))
print("4、字典为：{}".format(数学成绩.items()))
# Out:
# 1、张三的数学成绩为：88
# 2、键为：dict_keys(['张三', '李四', '王五'])
# 3、值为：dict_values([88, 92, 78])
# 4、字典为：dict_items([('张三', 88), ('李四', 92), ('王五', 78)])

# %% [markdown]
# ## 数据类型：集合

# %%
S1 = {"a", "b", "c"}; S2 = set("bee")
print("1、S1={}, S2={}".format(S1, S2))
print("2、并集S1∪S2={}, 交集S1∩S2={}".format(S1|S2, S1&S2))
print("3、差集S1-S2={}, S2-S1={}".format(S1-S2, S2-S1))
print("4、补集S1-S2={}, S2-S1={}".format(S1^S2, S2^S1))
# Out:
# 1、S1={'c', 'a', 'b'}, S2={'e', 'b'}
# 2、并集S1∪S2={'a', 'e', 'c', 'b'}, 交集S1∩S2={'b'}
# 3、差集S1-S2={'c', 'a'}, S2-S1={'e'}
# 4、补集S1-S2={'c', 'a', 'e'}, S2-S1={'c', 'a', 'e'}

# %% [markdown]
# ## 数据框：DataFrame

# %%
import pandas as pd

# %% [markdown]
# ### # 创建 DataFrame

# %%
# 创建 DataFrame，通过字典
dict1 = {"姓名":["张三","李四"],  "数学":[88,92], "英语":[85,75]}
df1 = pd.DataFrame(dict1)
df1
# Out:
#    姓名  数学  英语
# 0  张三  88  85
# 1  李四  92  75

# %%
# 创建 空 DataFrame
df2 = pd.DataFrame(columns=["姓名",  "数学", "英语"])
df2.loc[0]=["张三",88,85]		# 
df2.loc[1]=["李四",92,75]
df2
# Out:
#    姓名  数学  英语
# 0  张三  88  85
# 1  李四  92  75

# %% [markdown]
# ### DataFrame引用

# %%
df2["姓名"]    # 引用单列
# Out:
# 0    张三
# 1    李四
# Name: 姓名, dtype: object

# %%
df2[["姓名",  "数学"]]    # 采用列表引用多列
# Out:
#    姓名  数学
# 0  张三  88
# 1  李四  92

# %%
df2.loc[0]    # 参数为行标签(若有的话)
# Out:
# 姓名    张三
# 数学    88
# 英语    85
# Name: 0, dtype: object

# %%
df2.iloc[0]    # 参数为序列号
# Out:
# 姓名    张三
# 数学    88
# 英语    85
# Name: 0, dtype: object

# %%
df2.head()
# Out:
#    姓名  数学  英语
# 0  张三  88  85
# 1  李四  92  75

# %% [markdown]
# ### DataFrame修改、增、删

# %%
# 修改
df3 = df2.copy(); df3["姓名"][0] = "王五"    # 避免改动原数据集
df3
# Out:
# /tmp/ipykernel_10021/75826585.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3 = df2.copy(); df3["姓名"][0] = "王五"    # 避免改动原数据集
#    姓名  数学  英语
# 0  王五  88  85
# 1  李四  92  75

# %%
# 增加行
df3 = df2.copy()
df3.loc[3,:]=["王五", 70,70]   # 增加行
df3
# Out:
#    姓名    数学    英语
# 0  张三  88.0  85.0
# 1  李四  92.0  75.0
# 3  王五  70.0  70.0

# %%
# 增加列
df3 = df2.copy()
df3["平均"]=df3[["数学","英语"]].mean(axis=1)   # 增加列
df3
# Out:
#    姓名  数学  英语    平均
# 0  张三  88  85  86.5
# 1  李四  92  75  83.5

# %%
df2.drop(0,axis=0)    # axis=0 指定删除行
# Out:
#    姓名  数学  英语
# 1  李四  92  75

# %%
df2.drop(["数学"],axis=1)    # axis=1 指定删除列
# Out:
#    姓名  英语
# 0  张三  85
# 1  李四  75

# %%
df2.drop(columns=["数学"])    # columns= 指定删除列
# Out:
#    姓名  英语
# 0  张三  85
# 1  李四  75

# %%
df2.drop(columns=["数学"],inplace=True)    # inplace=True 彻底删除
df2
# Out:
#    姓名  英语
# 0  张三  85
# 1  李四  75

# %% [markdown]
# ## 判断与循环
# * python 中 for 常与 range()函数配合，遍历数字序列
# ### 例1：九九乘法表

# %%
# 九九乘法表
for i in range(1,10):
    for j in range(1,i+1):
        print("{0}×{1}={2}".format(i,j,i*j), end = '\t')
    print()
# Out:
# 1×1=1
# 2×1=2	2×2=4
# 3×1=3	3×2=6	3×3=9
# 4×1=4	4×2=8	4×3=12	4×4=16
# 5×1=5	5×2=10	5×3=15	5×4=20	5×5=25
# 6×1=6	6×2=12	6×3=18	6×4=24	6×5=30	6×6=36
# 7×1=7	7×2=14	7×3=21	7×4=28	7×5=35	7×6=42	7×7=49
# 8×1=8	8×2=16	8×3=24	8×4=32	8×5=40	8×6=48	8×7=56	8×8=64
# 9×1=9	9×2=18	9×3=27	9×4=36	9×5=45	9×6=54	9×7=63	9×8=72	9×9=81

# %% [markdown]
# ### 例2：简化for循环，生成列表、集合、字典等

# %%
# 将数字序列转为字符列表，可用于批量提取信息
L_num1 = range(1,10)
L_str = [ '序号' + str(i) for i in L_num1]
print(L_str)
L_num2 = [ int(item[2]) for item in L_str ]
print(L_num2)
# Out:
# ['序号1', '序号2', '序号3', '序号4', '序号5', '序号6', '序号7', '序号8', '序号9']
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# # 存取数据
# # 基本绘图命令
# 以matplotlib为例
# ## 简例
# 目前常用matplotlib.pyplot模块，处理了大量细节如图例和坐标轴等，从而用户可专注于数据分析.\
# 可以类似matlab作图

# %%
# 导入需要的包，并命名为常用别名
import matplotlib.pyplot as plt   # 用于作图
import numpy as np                # 用于数学和处理数据

# %%
# 生成数据
x = np.arange(0, 2*np.pi, 0.1)
y = np.sin(x)
# 绘制图形
plt.plot(x,y)
# 保存图形
# plt.savefig("D:/杜鸿飞/教学/多元统计分析/pic/2.2 Python基础/2.2 图形演示_简例.jpg",dpi=600) 
# 显示图形
plt.show()

# %% [markdown]
# ## 线型、点型、颜色

# %%
x = np.arange(0, 2*np.pi, 0.1)
y1 = np.sin(x);  y2 = x + y1;   y3 = x * y1;
plt.plot(x,y1,'b-')
plt.plot(x,y2,'c--')
plt.plot(x,y3,'r*', lw = 0.5)
# 保存图形
# plt.savefig("D:/杜鸿飞/教学/多元统计分析/pic/2.2 Python基础/2.2 图形演示_点、线、色.jpg",dpi=600) 
plt.show()

# %% [markdown]
# ## 横线、竖线、多图

# %%
# 横线和竖线, color、linstyle等不能省略
plt.axhline(y=0.5, color='r', linestyle='-')		# 过 y=0.5 的横线
plt.axvline(x=0.5, color='m', linestyle='--')		# 过 x=0.5 的竖线
plt.hlines(0, -3, 3,color="b", linestyle='-.')#横线
plt.vlines(1, -2, 3,color="c", linestyle=':')#竖线
# 保存图形
# plt.savefig("D:/杜鸿飞/教学/多元统计分析/pic/2.2 Python基础/2.2 图形演示_横线和竖线.jpg",dpi=600) 
plt.show()

# %%
# 多幅图设置
# 准备好数据
x = np.linspace(0,10,100)
y1 = x;    y2 = -x;
y3 = np.sin(x);    y4 = np.cos(x)

# 两行两列图形，但第二行仅一幅图
plt.figure(1)
plt.subplot(2,2,1);  plt.plot(x,y1)
plt.subplot(2,2,2);  plt.plot(x,y2)
plt.subplot(2,1,2);  plt.plot(x,y3)
# plt.savefig("D:/杜鸿飞/教学/多元统计分析/pic/2.2 Python基础/2.2 图形演示_多幅图1.jpg",dpi=600) 
# 两行两列图形，采用ax[]形式引用
fig, ax = plt.subplots(2,2)  
ax[0,0].plot(x,y1)
ax[0,1].plot(x,y2)
ax[1,0].plot(x,y3)
ax[1,1].plot(x,y4)
# plt.savefig("D:/杜鸿飞/教学/多元统计分析/pic/2.2 Python基础/2.2 图形演示_多幅图2.jpg",dpi=600) 
plt.show()

# %% [markdown]
# ## 标题、图例、文本、中文显示

# %%
# 标题
x = np.linspace(0,10,100)
y1 = x;    y2 = -x;
y3 = np.sin(x);    y4 = np.cos(x)

# 两行两列图形，但第二行仅一幅图
fig, ax = plt.subplots(2,2)  
fig.suptitle("suptitle")  # 大标题，放在图形之前，否则显示可能不正确
fig.tight_layout()    # 避免标题与子图重叠，plt绘图时用 plt.tight_layout
ax[0,0].plot(x,y1);  ax[0,0].set_title("fig1")
ax[0,1].plot(x,y2);  ax[0,1].set_title("fig2")
ax[1,0].plot(x,y3);  ax[1,0].set_title("fig3")
ax[1,1].plot(x,y4);  ax[1,1].set_title("fig4")

# plt.savefig("D:/杜鸿飞/教学/多元统计分析/pic/2.2 Python基础/2.2 图形演示_标题.jpg",dpi=600) 
plt.show()

# %%
# 图例
x = np.linspace(0,10,100); y1 = np.sin(x); y2 = np.cos(x)
plt.plot(x,y1,'r*', label='$sin(x)$')
plt.plot(x,y2,ls='-',lw=1, label='$cos(x)$') # ls--linestyle, lw--linewidth
plt.title("Legend Demo1")
plt.legend(loc='best', fontsize=12, frameon=True) 
# plt.savefig("D:/杜鸿飞/教学/多元统计分析/pic/2.2 Python基础/2.2 图形演示_图例1.jpg",dpi=600) 
plt.show()
# 另一设置图例方法：绘制图形，赋值给变量 以便后续引用
plt.figure()    # 新建一个图形，以免覆盖原来图形
pic = plt.plot(x,y1,'r*', x,y2,ls='-',lw=1) # ls 即 linestyle 
plt.title("Legend Demo2")
# print("pic={}".format(pic))  # 图形变量是数组
plt.legend((pic[0], pic[1]), ('$sin(x)$', '$cos(x)$'), loc=2) # loc= 不同数字对应不同位置
# plt.savefig("D:/杜鸿飞/教学/多元统计分析/pic/2.2 Python基础/2.2 图形演示_图例2.jpg",dpi=600) 
plt.show()

# %%
# 文本
fig, ax = plt.subplots(figsize=(6,4))

plt.plot(range(10))
plt.text(0.5, 0.5, 'matplotlib', horizontalalignment='center',
   verticalalignment='center', transform=ax.transAxes)
plt.text(2, 6, 'bbox example', bbox=dict(facecolor='pink', alpha=0.5), fontsize=18,rotation=20)
# plt.savefig("D:/杜鸿飞/教学/多元统计分析/pic/2.2 Python基础/2.2 图形演示_文本.jpg",dpi=600) 
plt.show()

# %%
# 中文显示
# 最初设置加载项
# ChinaFonts = {"黑体":"simhei",  "宋体":"simsun", "华文楷体":"STKAITI",  "华文新魏":"STXINWEI"}
# plt.rcParams["font.sans-serif"] = ChinaFonts["华文楷体"] # 指定文字为某种中文字体
plt.rcParams["font.sans-serif"] = "SimHei"
plt.rcParams["axes.unicode_minus"] = False # 解决负号无法正常显示的问题
plt.rcParams["text.usetex"]=True           # 开 手写体公式，Latex格式，但文本内不能有中文

# 准备好数据
x = np.linspace(0,10,100); y = np.sin(x)

# 绘制图形，添加标题
plt.plot(x,y)
plt.title("No Chinese words: $y=\sin(x)$") # 这里$y=sin(x)$是Latex格式的数学公式，用一对$ $括起来
plt.text(2,-0.5, 'No Chinese words: $f(x) = x^3 + 2x^2 + 3x$',fontsize=18)

# 所有title()和text()不能直接用中文，否则会报错；需关闭plt.rcParams["text.usetex"]=True才行
plt.rcParams["text.usetex"]=False   # 关 手写体公式，Latex格式，之后中文可正常显示

plt.text(3,0.5, r'环境中文字体 $f(x) = x^3 + 2x^2 + 3x}$')
plt.text(2,0,'指定其他中文字体 $f(x) = x^3 + 2x^2 + 3x$',fontproperties='SimHei')
# plt.savefig("D:/杜鸿飞/教学/多元统计分析/pic/2.2 Python基础/2.2 图形演示_中文显示.jpg",dpi=600) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/texmanager.py:253, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     252 try:
# --> 253     report = subprocess.check_output(
#     254         command, cwd=cwd if cwd is not None else cls.texcache,
#     255         stderr=subprocess.STDOUT)
#     256 except FileNotFoundError as exc:
#
# File /opt/anaconda/envs/data-science/lib/python3.10/subprocess.py:421, in check_output(timeout, *popenargs, **kwargs)
#     419     kwargs['input'] = empty
# --> 421 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     422            **kwargs).stdout
#
# File /opt/anaconda/envs/data-science/lib/python3.10/subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     501     kwargs['stderr'] = PIPE
# --> 503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
#
# File /opt/anaconda/envs/data-science/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#
# File /opt/anaconda/envs/data-science/lib/python3.10/subprocess.py:1847, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1846         err_msg = os.strerror(errno_num)
# -> 1847     raise child_exception_type(errno_num, err_msg, err_filename)
#    1848 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/backend_bases.py:2314, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2308     renderer = _get_renderer(
#    2309         self.figure,
#    2310         functools.partial(
#    2311             print_method, orientation=orientation)
#    2312     )
#    2313     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2314         self.figure.draw(renderer)
#    2316 if bbox_inches:
#    2317     if bbox_inches == "tight":
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/figure.py:3071, in Figure.draw(self, renderer)
#    3068         # ValueError can occur when resizing a window.
#    3070 self.patch.draw(renderer)
# -> 3071 mimage._draw_list_compositing_images(
#    3072     renderer, self, artists, self.suppressComposite)
#    3074 for sfig in self.subfigs:
#    3075     sfig.draw(renderer)
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/axes/_base.py:3071, in _AxesBase.draw(self, renderer)
#    3068     for spine in self.spines.values():
#    3069         artists.remove(spine)
# -> 3071 self._update_title_position(renderer)
#    3073 if not self.axison:
#    3074     for _axis in self._axis_map.values():
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/axes/_base.py:3015, in _AxesBase._update_title_position(self, renderer)
#    3013 top = max(top, bb.ymax)
#    3014 if title.get_text():
# -> 3015     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3016     if ax.yaxis.offsetText.get_text():
#    3017         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/axis.py:1253, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1250     renderer = self.figure._get_renderer()
#    1251 ticks_to_draw = self._update_ticks()
# -> 1253 self._update_label_position(renderer)
#    1255 # go back to just this axis's tick labels
#    1256 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/axis.py:2506, in YAxis._update_label_position(self, renderer)
#    2502     return
#    2504 # get bounding boxes for this axis and any siblings
#    2505 # that have been set by `fig.align_ylabels()`
# -> 2506 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2507 x, y = self.label.get_position()
#    2508 if self.label_position == 'left':
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/axis.py:2056, in Axis._get_tick_boxes_siblings(self, renderer)
#    2054 axis = getattr(ax, f"{axis_name}axis")
#    2055 ticks_to_draw = axis._update_ticks()
# -> 2056 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2057 bboxes.extend(tlb)
#    2058 bboxes2.extend(tlb2)
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/axis.py:1232, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1230 if renderer is None:
#    1231     renderer = self.figure._get_renderer()
# -> 1232 return ([tick.label1.get_window_extent(renderer)
#    1233          for tick in ticks if tick.label1.get_visible()],
#    1234         [tick.label2.get_window_extent(renderer)
#    1235          for tick in ticks if tick.label2.get_visible()])
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/axis.py:1232, in <listcomp>(.0)
#    1230 if renderer is None:
#    1231     renderer = self.figure._get_renderer()
# -> 1232 return ([tick.label1.get_window_extent(renderer)
#    1233          for tick in ticks if tick.label1.get_visible()],
#    1234         [tick.label2.get_window_extent(renderer)
#    1235          for tick in ticks if tick.label2.get_visible()])
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/text.py:915, in Text.get_window_extent(self, renderer, dpi)
#     910     raise RuntimeError(
#     911         "Cannot get window extent of text w/o renderer. You likely "
#     912         "want to call 'figure.draw_without_rendering()' first.")
#     914 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 915     bbox, info, descent = self._get_layout(self._renderer)
#     916     x, y = self.get_unitless_position()
#     917     x, y = self.get_transform().transform((x, y))
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/text.py:313, in Text._get_layout(self, renderer)
#     310 ys = []
#     312 # Full vertical extent of font, including ascenders and descenders:
# --> 313 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     314     renderer, "lp", self._fontproperties,
#     315     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     316 min_dy = (lp_h - lp_d) * self._linespacing
#     318 for i, line in enumerate(lines):
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/text.py:97, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      94 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      95 # Cached based on a copy of fontprop so that later in-place mutations of
#      96 # the passed-in argument do not mess up the cache.
# ---> 97 return _get_text_metrics_with_cache_impl(
#      98     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/text.py:105, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#     101 @functools.lru_cache(4096)
#     102 def _get_text_metrics_with_cache_impl(
#     103         renderer_ref, text, fontprop, ismath, dpi):
#     104     # dpi is unused, but participates in cache invalidation (via the renderer).
# --> 105     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:229, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     227     texmanager = self.get_texmanager()
#     228     fontsize = prop.get_size_in_points()
# --> 229     w, h, d = texmanager.get_text_width_height_descent(
#     230         s, fontsize, renderer=self)
#     231     return w, h, d
#     233 if ismath:
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/texmanager.py:362, in TexManager.get_text_width_height_descent(cls, tex, fontsize, renderer)
#     360 if tex.strip() == '':
#     361     return 0, 0, 0
# --> 362 dvifile = cls.make_dvi(tex, fontsize)
#     363 dpi_fraction = renderer.points_to_pixels(1.) if renderer else 1
#     364 with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/texmanager.py:295, in TexManager.make_dvi(cls, tex, fontsize)
#     286     # Generate the dvi in a temporary directory to avoid race
#     287     # conditions e.g. if multiple processes try to process the same tex
#     288     # string at the same time.  Having tmpdir be a subdirectory of the
#    (...)
#     292     # the absolute path may contain characters (e.g. ~) that TeX does
#     293     # not support.)
#     294     with TemporaryDirectory(dir=Path(dvifile).parent) as tmpdir:
# --> 295         cls._run_checked_subprocess(
#     296             ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     297              f"../{texfile.name}"], tex, cwd=tmpdir)
#     298         (Path(tmpdir) / Path(dvifile).name).replace(dvifile)
#     299 return dvifile
#
# File /opt/anaconda/envs/data-science/lib/python3.10/site-packages/matplotlib/texmanager.py:257, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     253     report = subprocess.check_output(
#     254         command, cwd=cwd if cwd is not None else cls.texcache,
#     255         stderr=subprocess.STDOUT)
#     256 except FileNotFoundError as exc:
# --> 257     raise RuntimeError(
#     258         'Failed to process string with tex because {} could not be '
#     259         'found'.format(command[0])) from exc
#     260 except subprocess.CalledProcessError as exc:
#     261     raise RuntimeError(
#     262         '{prog} was not able to process the following string:\n'
#     263         '{tex!r}\n\n'
#    (...)
#     270             exc=exc.output.decode('utf-8', 'backslashreplace'))
#     271         ) from None
#
# RuntimeError: Failed to process string with tex because latex could not be found

# %% [markdown]
# # 常见问题

# %%
# 变量与地址
a = [1, 2, 3];  b = a; c = a.copy()		# 直接等号赋值，地址相同
print("a={},  b={}, c={}".format(a,b,c))
print("id(a)= {}，id(b)= {}，id(c)= {}".format(id(a), id(b), id(c)))
b[1] = 9     # 改变 b 会导致 a 跟随变化
print("a={},  b={}, c={}".format(a,b,c))
# Out:
# a=[1, 2, 3],  b=[1, 2, 3], c=[1, 2, 3]
# id(a)= 139965938675392，id(b)= 139965938675392，id(c)= 139965939357888
# a=[1, 9, 3],  b=[1, 9, 3], c=[1, 2, 3]

# %%
# 图形的中文出现乱码
import matplotlib.pyplot as plt
plt.plot(range(10))
plt.title("中文标题")
# plt.savefig("C:/code/python/multifed_stas/图形演示_中文乱码.jpg",dpi=600) 
plt.show()

# %%
# 解决中文乱码问题
ChinaFonts = {"黑体":"simhei",
             "宋体":"simsun",
             "华文彩云":"STCAIYUN",
             "华文琥珀":"STHUPO",
             "华文楷体":"STKAITI",
             "华文隶书":"STLITI",
             "华文宋体":"STSONG",
             "华文细黑":"STXIHEI",
             "华文新魏":"STXINWEI"}
plt.rc('font', family=ChinaFonts["华文宋体"])
plt.rc('axes', unicode_minus=False) #解决负号无法正常显示的问题(明显偏大)
plt.plot(range(10))
plt.title("中文标题")
# plt.savefig("C:/code/python/multifed_stas/图形演示_中文乱码.jpg",dpi=600) 
plt.show()
