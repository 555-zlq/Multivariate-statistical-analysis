# %% [markdown]
# # 第一次作业
# ## 2020080301001 张力群
# ## 作业要求
# 读入数据，统计各地区的上市公司数目，并选择适当方
# 法可视化展示 —— 尽量尝试对可视化图形进行适当的修饰；

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  # 统计数据可视化
# 绘图风格： style= ["darkgrid"，"whitegrid"，"dark"，"white"，"ticks"]，默认darkgrid
sns.set_style(style="darkgrid")
# 颜色风格： themes = ['deep', 'muted', 'pastel', 'bright', 'dark', 'colorblind']
sns.set_palette(palette='bright')
ChinaFonts = {"黑体": "simhei", "宋体": "simsun", "华文楷体": "STKAITI"}
plt.rcParams["font.sans-serif"] = ChinaFonts["华文楷体"]  # 解决中文乱码问题
plt.rcParams["axes.unicode_minus"] = False  # 解决负号无法正常显示的问题
path_data = "C:/code/python/multifed_stas/database/"  # 设置 数据路径
path_pic = "C:/code/python/multifed_stas/save_database/"  # 设置 图像保存路径

# %% [markdown]
# ### 读入数据

# %%
regional_file = path_data + "地区板块.txt" # 板块分析结果文件名，含路径
df_regionalCode = pd.read_csv(regional_file, encoding="gbk", sep="\t", dtype=str,names=["板块代码", "板块名称", "股票代码", "股票名称"])
df_regionalCode
# Out:
#         板块代码  板块名称    股票代码   股票名称
# 0     880201   黑龙江  000587  *ST金洲
# 1     880201   黑龙江  000711   京蓝科技
# 2     880201   黑龙江  000901   航天科技
# 3     880201   黑龙江  000922   佳电股份
# 4     880201   黑龙江  000985   大庆华科
# ...      ...   ...     ...    ...
# 4984  880232  内蒙板块  600967   内蒙一机
# 4985  880232  内蒙板块  600988   赤峰黄金
# 4986  880232  内蒙板块  601216   君正集团
# 4987  880232  内蒙板块  603230   内蒙新华
# 4988  880232  内蒙板块  836433   大唐药业
#
# [4989 rows x 4 columns]

# %% [markdown]
# ### 可视化

# %%
df_regionalCode['板块名称'].value_counts().plot(kind="barh", fontsize=8, figsize=(12,8))
plt.title('地区板块条形图', fontsize=14)
plt.show()

# %%
# !pip install -U notebook-as-pdf
# Out:
# Collecting notebook-as-pdf
#   Downloading notebook_as_pdf-0.5.0-py3-none-any.whl (6.5 kB)
# Collecting pyppeteer
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      -------------------------------------- 83.4/83.4 KB 664.9 kB/s eta 0:00:00
# Collecting nbconvert
#   Downloading nbconvert-7.2.5-py3-none-any.whl (273 kB)
#      ------------------------------------ 273.3/273.3 KB 240.4 kB/s eta 0:00:00
# Collecting PyPDF2
#   Downloading pypdf2-2.11.2-py3-none-any.whl (220 kB)
#      ------------------------------------ 220.6/220.6 KB 120.2 kB/s eta 0:00:00
# Requirement already satisfied: pygments>=2.4.1 in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from nbconvert->notebook-as-pdf) (2.12.0)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ------------------------------------- 128.2/128.2 KB 18.1 kB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=3.6 in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from nbconvert->notebook-as-pdf) (4.11.3)
# Collecting nbformat>=5.1
#   Downloading nbformat-5.7.0-py3-none-any.whl (77 kB)
#      --------------------------------------- 77.1/77.1 KB 35.7 kB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from nbconvert->notebook-as-pdf) (21.3)
# Requirement already satisfied: traitlets>=5.0 in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from nbconvert->notebook-as-pdf) (5.2.2.post1)
# Collecting mistune<3,>=2.0.3
#   Downloading mistune-2.0.4-py2.py3-none-any.whl (24 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting jupyter-core>=4.7
#   Downloading jupyter_core-5.0.0-py3-none-any.whl (91 kB)
#      --------------------------------------- 91.1/91.1 KB 23.9 kB/s eta 0:00:00
# Requirement already satisfied: markupsafe>=2.0 in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from nbconvert->notebook-as-pdf) (2.1.1)
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: jinja2>=3.0 in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from nbconvert->notebook-as-pdf) (3.1.2)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting bleach
#   Downloading bleach-5.0.1-py3-none-any.whl (160 kB)
#      ------------------------------------- 160.9/160.9 KB 27.0 kB/s eta 0:00:00
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.7.0-py3-none-any.whl (71 kB)
#      --------------------------------------- 71.9/71.9 KB 23.2 kB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from PyPDF2->notebook-as-pdf) (4.2.0)
# Requirement already satisfied: certifi>=2021 in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from pyppeteer->notebook-as-pdf) (2021.10.8)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Collecting appdirs<2.0.0,>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from pyppeteer->notebook-as-pdf) (1.26.9)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.4-cp38-cp38-win_amd64.whl (101 kB)
#      ------------------------------------- 101.4/101.4 KB 29.3 kB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from pyppeteer->notebook-as-pdf) (4.64.0)
# Requirement already satisfied: zipp>=0.5 in c:\enviroment\anaconda\envs\tensorflow\lib\site-packages (from importlib-metadata>=3.6->nbconvert->notebook-as-pdf) (3.8.0)
# Collecting platformdirs
#   Downloading platformdirs-2.5.4-py3-none-any.whl (14 kB)
# Collecting pywin32>=1.0
#   Downloading pywin32-305-cp38-cp38-win_amd64.whl (12.3 MB)
#      ----                                     1.4/12.3 MB 14.4 kB/s eta 0:12:40
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027CEA22B7C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/notebook-as-pdf/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027CEA22BAC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/notebook-as-pdf/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027CEA22BD30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/notebook-as-pdf/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027CEA22BEE0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/notebook-as-pdf/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027CEA22BDF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/notebook-as-pdf/
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/be/aa/33c6dc40a09b01d77a657e95461932463e4c061ba623e6bbc4f6ab15634d/notebook_as_pdf-0.5.0-py3-none-any.whl
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/pypdf2/
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\http\client.py", line 459, in read
#     n = self.readinto(b)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\http\client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\cli\base_command.py", line 167, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\cli\req_command.py", line 205, in wrapper
#     return func(self, options, args)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\commands\install.py", line 339, in run
#     requirement_set = resolver.resolve(
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 94, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 481, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 373, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 213, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 204, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 215, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 288, in __init__
#     super().__init__(
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 158, in __init__
#     self.dist = self._prepare()
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 227, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 299, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\operations\prepare.py", line 487, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\operations\prepare.py", line 532, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\operations\prepare.py", line 214, in unpack_url
#     file = get_http_url(
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\operations\prepare.py", line 94, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\network\download.py", line 146, in __call__
#     for chunk in chunks:
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\cli\progress_bars.py", line 304, in _rich_progress_bar
#     for chunk in iterable:
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_internal\network\utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\enviroment\anaconda\envs\tensorflow\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
